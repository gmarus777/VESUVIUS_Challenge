# %%
# Here we take care of paths.
# Make sure root project directory is named 'VESUVIUS_Challenge' for this to work

from pathlib import Path
import os
print('Starting path:' + os.getcwd())
if os.getcwd()[-18:] == 'VESUVIUS_Challenge':
    pass
else:
    PATH = Path().resolve().parents[0]
    os.chdir(PATH)

# make sure you are in the root folder of the project
print('Current path:' + os.getcwd())
# Out:
# Starting path:/Users/gregory/PROJECT_ML/VESUVIUS_Challenge/jupyter notebooks
# Current path:/Users/gregory/PROJECT_ML/VESUVIUS_Challenge

# %%
import torch
import monai
from monai.visualize import matshow3d
import segmentation_models_pytorch as smp
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob
import cv2
import numpy as np
import pandas as pd
from tqdm.auto import tqdm
from typing import Tuple, List
import albumentations as A
from albumentations.pytorch import ToTensorV2
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from Data_Modules.Vesuvius_Dataset import Vesuvius_Tile_Datamodule
from lit_models.Vesuvius_Lit_Model import Lit_Model
from pytorch_lightning.callbacks import ModelCheckpoint
import gc
from torch.utils.data import DataLoader, Dataset
# Out:
# 2023-05-11 11:18:31,039 - Created a temporary directory at /var/folders/wc/60y8v25x3ns_jgsx6clbdb180000gn/T/tmp2r_dab4l
# 2023-05-11 11:18:31,039 - Writing /var/folders/wc/60y8v25x3ns_jgsx6clbdb180000gn/T/tmp2r_dab4l/_remote_module_non_scriptable.py

# %%
CHECKPOINT = 'logs/2BCE05_09tver_alpha08_Monai_FlexU3/BCE02_tver_alpha08_SMPB3epoch=30FBETA=0.43val_loss=0.73fbeta_4=0.16recall=0.47precision=0.67.ckpt'
SAMPLE_SUBMISSION = 'kaggle/input/vesuvius-challenge-ink-detection/sample_submission.csv'


DEVICE = torch.device("cuda" if torch.cuda.is_available() else "mps")

# change to the line below if not using Apple's M1 or chips
# DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
PATCH_SIZE = 224
Z_DIM = 16
COMPETITION_DATA_DIR_str =  "kaggle/input/vesuvius-challenge-ink-detection/"

class CFG:
    
    device = DEVICE
    
    THRESHOLD = 0.5
    use_wandb = False
    
    ######### Dataset #########
    
    # stage: 'train' or 'test'
    stage = 'test' 
    
    # location of competition Data
    competition_data_dir = COMPETITION_DATA_DIR_str
    
    # Number of slices in z-dim: 1<z_dim<65
    z_dim = Z_DIM
    
    # fragments to use for training avalaible [1,2,3]
    train_fragment_id=[2,3]
    
    # fragments to use for validation
    val_fragment_id=[1]
    
    test_fragment_ids = ['a','b']
    
    

    
    
    batch_size = 16
    
    # Size of the patch and stride for feeding the model
    patch_size = PATCH_SIZE
    stride = patch_size // 4
    
    
    num_workers = 0
    on_gpu = True
    
    
    ######## Model and Lightning Model paramters ############
    
    # MODEL
    model = monai.networks.nets.FlexibleUNet(in_channels=z_dim,
                                         out_channels=1,
                                         backbone='efficientnet-b3',
                                         pretrained=True,
                                         decoder_channels=( 512, 256, 128, 64, 32),
                                         spatial_dims=2,
                                         norm=('batch', {'eps': 0.001, 'momentum': 0.1}),
                                         # act=('relu', {'inplace': True}),
                                         act=None,
                                         dropout=0.0,
                                         decoder_bias=False,
                                         upsample='deconv',
                                         interp_mode='nearest',
                                         is_pad=False)
   
    
    
    
    checkpoint = None
    save_directory = None
    
    
    accumulate_grad_batches = 192// batch_size  # experiments showed batch_size * accumulate_grad = 192 is optimal
    learning_rate = 0.0001
    eta_min = 1e-8
    t_max = 80
    max_epochs = 120
    weight_decay =  0.0001
    precision =16
    
    # checkpointing
    save_top_k=5
    
    monitor="FBETA"
    mode="max"
    
    
    ####### Augemtnations ###############
    
    # Training Aug
    train_transforms = [
        # A.RandomResizedCrop(
        #     size, size, scale=(0.85, 1.0)),
        A.Resize(patch_size, patch_size),
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomBrightnessContrast(p=0.75),
        A.ShiftScaleRotate(p=0.75),
        A.OneOf([
                A.GaussNoise(var_limit=[10, 50]),
                A.GaussianBlur(),
                A.MotionBlur(),
                ], p=0.4),
        A.GridDistortion(num_steps=5, distort_limit=0.3, p=0.5),
        A.CoarseDropout(max_holes=1, max_width=int(patch_size * 0.3), max_height=int(patch_size * 0.3), 
                        mask_fill_value=0, p=0.5),
        # A.Cutout(max_h_size=int(size * 0.6),
        #          max_w_size=int(size * 0.6), num_holes=1, p=1.0),
        A.Normalize(
            mean= [0] * z_dim,
            std= [1] * z_dim
        ),
        ToTensorV2(transpose_mask=True),
    ]
    

    
    # Validaiton Aug
    val_transforms = [
        A.Resize(patch_size, patch_size),
        A.Normalize(
            mean= [0] * z_dim,
            std= [1] * z_dim
        ),
        ToTensorV2(transpose_mask=True),
    ]
    
    # Test Aug
    test_transforms = [
        A.Resize(patch_size, patch_size),
        A.Normalize(
            mean=[0] * z_dim,
            std=[1] * z_dim
        ),

        ToTensorV2(transpose_mask=True),
    ]

# %%
lit_model = Lit_Model(cfg=CFG)

lit_model = lit_model.load_from_checkpoint(CHECKPOINT, cfg=CFG,).to(CFG.device)

lit_model.eval()
# Out:
# Lit_Model(
#   (metrics): ModuleDict(
#     (train_metrics): MetricCollection(
#       (dice): Dice(),
#       prefix=train_
#     )
#     (val_metrics): MetricCollection(
#       (dice): Dice(),
#       prefix=val_
#     )
#   )
#   (model): FlexibleUNet(
#     (encoder): EfficientNetEncoder(
#       (_conv_stem): Conv2d(16, 40, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (_conv_stem_padding): ConstantPad2d(padding=(0, 1, 0, 1), value=0.0)
#       (_bn0): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (_blocks): Sequential(
#         (0): Sequential(
#           (0): MBConvBlock(
#             (_expand_conv): Identity()
#             (_expand_conv_padding): Identity()
#             (_bn0): Identity()
#             (_depthwise_conv): Conv2d(40, 40, kernel_size=(3, 3), stride=(1, 1), groups=40, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(40, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(40, 10, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(10, 40, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(40, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (1): MBConvBlock(
#             (_expand_conv): Identity()
#             (_expand_conv_padding): Identity()
#             (_bn0): Identity()
#             (_depthwise_conv): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), groups=24, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#         )
#         (1): Sequential(
#           (2): MBConvBlock(
#             (_expand_conv): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), groups=144, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(0, 1, 0, 1), value=0.0)
#             (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (3): MBConvBlock(
#             (_expand_conv): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (4): MBConvBlock(
#             (_expand_conv): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), groups=192, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#         )
#         (2): Sequential(
#           (5): MBConvBlock(
#             (_expand_conv): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), groups=192, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (6): MBConvBlock(
#             (_expand_conv): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (7): MBConvBlock(
#             (_expand_conv): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), groups=288, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#         )
#         (3): Sequential(
#           (8): MBConvBlock(
#             (_expand_conv): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), groups=288, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(0, 1, 0, 1), value=0.0)
#             (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(288, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (9): MBConvBlock(
#             (_expand_conv): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (10): MBConvBlock(
#             (_expand_conv): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (11): MBConvBlock(
#             (_expand_conv): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (12): MBConvBlock(
#             (_expand_conv): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), groups=576, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(96, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#         )
#         (4): Sequential(
#           (13): MBConvBlock(
#             (_expand_conv): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(576, 576, kernel_size=(5, 5), stride=(1, 1), groups=576, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(576, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(576, 24, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(24, 576, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(576, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (14): MBConvBlock(
#             (_expand_conv): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (15): MBConvBlock(
#             (_expand_conv): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (16): MBConvBlock(
#             (_expand_conv): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (17): MBConvBlock(
#             (_expand_conv): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(816, 816, kernel_size=(5, 5), stride=(1, 1), groups=816, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(816, 136, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(136, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#         )
#         (5): Sequential(
#           (18): MBConvBlock(
#             (_expand_conv): Conv2d(136, 816, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(816, 816, kernel_size=(5, 5), stride=(2, 2), groups=816, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(816, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(816, 34, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(34, 816, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(816, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (19): MBConvBlock(
#             (_expand_conv): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (20): MBConvBlock(
#             (_expand_conv): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (21): MBConvBlock(
#             (_expand_conv): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (22): MBConvBlock(
#             (_expand_conv): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (23): MBConvBlock(
#             (_expand_conv): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(1392, 1392, kernel_size=(5, 5), stride=(1, 1), groups=1392, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(2, 2, 2, 2), value=0.0)
#             (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(1392, 232, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(232, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#         )
#         (6): Sequential(
#           (24): MBConvBlock(
#             (_expand_conv): Conv2d(232, 1392, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(1392, 1392, kernel_size=(3, 3), stride=(1, 1), groups=1392, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(1392, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(1392, 58, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(58, 1392, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(1392, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#           (25): MBConvBlock(
#             (_expand_conv): Conv2d(384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_expand_conv_padding): Identity()
#             (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_depthwise_conv): Conv2d(2304, 2304, kernel_size=(3, 3), stride=(1, 1), groups=2304, bias=False)
#             (_depthwise_conv_padding): ConstantPad2d(padding=(1, 1, 1, 1), value=0.0)
#             (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_se_adaptpool): AdaptiveAvgPool2d(output_size=1)
#             (_se_reduce): Conv2d(2304, 96, kernel_size=(1, 1), stride=(1, 1))
#             (_se_reduce_padding): Identity()
#             (_se_expand): Conv2d(96, 2304, kernel_size=(1, 1), stride=(1, 1))
#             (_se_expand_padding): Identity()
#             (_project_conv): Conv2d(2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (_project_conv_padding): Identity()
#             (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#             (_swish): MemoryEfficientSwish()
#           )
#         )
#       )
#       (_conv_head): Conv2d(384, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (_conv_head_padding): Identity()
#       (_bn1): BatchNorm2d(1536, eps=0.001, momentum=0.01, affine=True, track_running_stats=True)
#       (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#       (_dropout): Dropout(p=0.3, inplace=False)
#       (_fc): Linear(in_features=1536, out_features=1000, bias=True)
#       (_swish): MemoryEfficientSwish()
#     )
#     (decoder): UNetDecoder(
#       (blocks): ModuleList(
#         (0): UpCat(
#           (upsample): UpSample(
#             (deconv): ConvTranspose2d(384, 192, kernel_size=(2, 2), stride=(2, 2))
#           )
#           (convs): TwoConv(
#             (conv_0): Convolution(
#               (conv): Conv2d(328, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (conv_1): Convolution(
#               (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(512, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#         (1): UpCat(
#           (upsample): UpSample(
#             (deconv): ConvTranspose2d(512, 256, kernel_size=(2, 2), stride=(2, 2))
#           )
#           (convs): TwoConv(
#             (conv_0): Convolution(
#               (conv): Conv2d(304, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (conv_1): Convolution(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#         (2): UpCat(
#           (upsample): UpSample(
#             (deconv): ConvTranspose2d(256, 128, kernel_size=(2, 2), stride=(2, 2))
#           )
#           (convs): TwoConv(
#             (conv_0): Convolution(
#               (conv): Conv2d(160, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (conv_1): Convolution(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#         (3): UpCat(
#           (upsample): UpSample(
#             (deconv): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#           )
#           (convs): TwoConv(
#             (conv_0): Convolution(
#               (conv): Conv2d(88, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (conv_1): Convolution(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#         (4): UpCat(
#           (upsample): UpSample(
#             (deconv): ConvTranspose2d(64, 64, kernel_size=(2, 2), stride=(2, 2))
#           )
#           (convs): TwoConv(
#             (conv_0): Convolution(
#               (conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (conv_1): Convolution(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (adn): ADN(
#                 (N): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#                 (D): Dropout(p=0.0, inplace=False)
#               )
#             )
#           )
#         )
#       )
#     )
#     (segmentation_head): SegmentationHead(
#       (0): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): Identity()
#       (2): Identity()
#     )
#   )
#   (loss_dice): DiceLoss()
#   (loss_tversky): TverskyLoss()
#   (loss_focal): FocalLoss()
#   (loss_bce): SoftBCEWithLogitsLoss()
#   (loss_monai_focal_dice): DiceFocalLoss(
#     (dice): DiceLoss()
#     (focal): FocalLoss()
#   )
# )

# %%
def make_test_dataset(fragment_id):
    test_images = read_image(fragment_id)
    
    x1_list = list(range(0, test_images.shape[1]-CFG.patch_size+1, CFG.stride))
    y1_list = list(range(0, test_images.shape[0]-CFG.patch_size+1, CFG.stride))
    
    test_images_list = []
    xyxys = []
    for y1 in y1_list:
        for x1 in x1_list:
            y2 = y1 + CFG.patch_size
            x2 = x1 + CFG.patch_size
            
            test_images_list.append(test_images[y1:y2, x1:x2])
            xyxys.append((x1, y1, x2, y2))
    xyxys = np.stack(xyxys)
            
    test_dataset = CustomDataset(test_images_list, CFG, transform=get_transforms(data='valid', cfg=CFG))
    
    test_loader = DataLoader(test_dataset,
                          batch_size=CFG.batch_size,
                          shuffle=False,
                          num_workers=CFG.num_workers, pin_memory=CFG.on_gpu, drop_last=False)
    
    return test_loader, xyxys


def get_transforms(data, cfg):
    return A.Compose(
        [
        A.Resize(CFG.patch_size, CFG.patch_size),
        A.Normalize(
            mean=[0] * CFG.z_dim,
            std=[1] * CFG.z_dim
        ),

        ToTensorV2(transpose_mask=True),
    ]
    )

def read_image(fragment_id):
    images = []

    # idxs = range(65)
    mid = 65 // 2
    start = mid - CFG.z_dim // 2
    end = mid + CFG.z_dim // 2
    idxs = range(start, end)

    for i in tqdm(idxs):
        
        image = cv2.imread(COMPETITION_DATA_DIR_str + f"test/{fragment_id}/surface_volume/{i:02}.tif", 0)

        pad0 = (CFG.patch_size - image.shape[0] % CFG.patch_size)
        pad1 = (CFG.patch_size - image.shape[1] % CFG.patch_size)

        image = np.pad(image, [(0, pad0), (0, pad1)], constant_values=0)

        images.append(image)
    images = np.stack(images, axis=2)
    
    return images

class CustomDataset(Dataset):
    def __init__(self, images, cfg, labels=None, transform=None):
        self.images = images
        self.cfg = cfg
        self.labels = labels
        self.transform = transform

    def __len__(self):
        # return len(self.xyxys)
        return len(self.images)

    def __getitem__(self, idx):
        # x1, y1, x2, y2 = self.xyxys[idx]
        image = self.images[idx]
        data = self.transform(image=image)
        image = data['image']
        return image
    
    
    
def rle(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = img.flatten()
    # pixels = (pixels >= thr).astype(int)
    
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
#224 stride=8
THRESHOLD =0.4
results = []
for fragment_id in CFG.test_fragment_ids:
    
    test_loader, xyxys = make_test_dataset(fragment_id)
    
    binary_mask = cv2.imread(COMPETITION_DATA_DIR_str + f"test/{fragment_id}/mask.png", 0)
    binary_mask = (binary_mask / 255).astype(int)
    binary_mask = torch.tensor(binary_mask)#.to(DEVICE)
    
    ori_h = binary_mask.shape[0]
    ori_w = binary_mask.shape[1]
    # mask = mask / 255

    pad0 = (CFG.patch_size - binary_mask.shape[0] % CFG.patch_size)
    pad1 = (CFG.patch_size - binary_mask.shape[1] % CFG.patch_size)

    binary_mask = np.pad(binary_mask, [(0, pad0), (0, pad1)], constant_values=0)
    
    mask_pred = torch.zeros(binary_mask.shape).to(CFG.device)
    mask_count = torch.zeros(binary_mask.shape).to(CFG.device)

    for step, (images) in tqdm(enumerate(test_loader), total=len(test_loader)):
        images = images.to(DEVICE)
        batch_size = images.size(0)
        
        with torch.no_grad():
            y_preds = lit_model(images)
            y_preds = torch.sigmoid(y_preds)
            #y_preds = y_preds.numpy()
            #print(type(y_preds))

        start_idx = step*CFG.batch_size
        end_idx = start_idx + batch_size
        #xyxys = torch.from_numpy(xyxys)
        for i, (x1, y1, x2, y2) in enumerate(xyxys[start_idx:end_idx]):
            mask_pred[y1:y2, x1:x2] += y_preds[i].squeeze(0)
            mask_count[y1:y2, x1:x2] += torch.ones((CFG.patch_size, CFG.patch_size)).to(DEVICE)
    
    plt.imshow(mask_count.to('cpu'))
    plt.show()
    
    print(f'mask_count_min: {mask_count.min()}')
    mask_pred /= mask_count
    
    mask_pred = mask_pred[:ori_h, :ori_w]
    binary_mask = binary_mask[:ori_h, :ori_w]
    
    mask_pred = mask_pred.to('cpu').numpy()
    mask_pred = (mask_pred >= THRESHOLD).astype(int)
    mask_pred *= binary_mask
    
    plt.imshow(mask_pred)
    plt.show()
    
    inklabels_rle = rle(mask_pred)
    
    
    results.append( inklabels_rle)
    

    del mask_pred, mask_count
    del test_loader
    
    gc.collect()
    torch.cuda.empty_cache()
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/347 [00:00<?, ?it/s]
# mask_count_min: 1.0
#   0%|          | 0/16 [00:00<?, ?it/s]
#   0%|          | 0/686 [00:00<?, ?it/s]
# mask_count_min: 1.0

# %%
submission_df = pd.read_csv(SAMPLE_SUBMISSION)

# %%
submission_df["Predicted"] = results
    
submission_df.to_csv("logs/submission.csv", index=False)

submission_df
# Out:
#   Id                                          Predicted
# 0  a  656885 1 656887 1 656889 1 656891 5 663219 3 6...
# 1  b  3620 5 16303 1 16305 1 20337 3 20341 1 22145 1...

# %% [markdown]
# ## Sliding window inference

# %%
# load images and run it
